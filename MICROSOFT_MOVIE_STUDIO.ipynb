# %% [markdown]
# <a href="https://colab.research.google.com/github/kenny067/dsc-project-template/blob/master/MICROSOFT_MOVIE_STUDIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROJECT: MOVIE STUDIO**

# %% [markdown]
# Microsoft decided to create a new movie studio for them to get in the fun of creating original video content.
# # DATASET
# I was charged with assesing what types of film are currently doing the best at the box office. May it be the comedy,documentary or even the action movies. This is done by using the IMDB files which shows the:
# * most watched film
# * top ranked film
# * list of film
#
#
# The IMDB file has six columns and one hundred and fourt six thousands one hundred and fourt four rows.

# %% [markdown]
# Prior to the analysis of the dataset, cleaning will be undertaken. This will involve the removal of repeated data,uniqueid column and the changing of the datatype.

# %% [markdown]
# The next move will be creation of new columns from the breaking of existing columns.
#
# First, we will create a new column named current_year to show which year we are in.
#
# Secondly, we create another column called 'age' which will calculate how old the film is by subtracting the start_year from the current_year.

# %% [markdown]
# To ensure the validity of the data we will then identify duplications in the dataset,removing all duplicates from the last column of the dataset.

# %% [markdown]
# The next column to be broken will be the genre column creating a new column called the most watched film which will identify the film with the most viewed film according to the descending order.
#
# After this, the data will be cleaned to sufficently

# %% [markdown]
# # 1.0 Import the libraries

# %%
#Import all import libraries : pandas and numpy
import pandas as pd #For manipulation of large datasets
import numpy as np #For manipulation of numeric array values.

# %% [markdown]
# # 2.0 Upload the datasets

# %%
#Uploading the dataset
# %run "/content/student.ipynb"

# %%
df=pd.read_csv("/content/imdb.title.basics.csv.gz")

# %% [markdown]
# # 3.0 Preview the data

# %%
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %% [markdown]
# # 4.0 Accesing Informatiion about our Dataset

# %%
# Begin to know more about our dataset by accessing its information
print(df.columns)#To identify column names.
print(df.shape)#To identify dataframe dimensions.
print(df.isnull().sum())#To list number of null values per column.
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')
# (146144, 6)
# tconst                 0
# primary_title          1
# original_title        22
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %% [markdown]
# # 4.1 Info about the Dataset

# %%
#To get to know the class of our dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146143 non-null  object
#  2   original_title   146122 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# # 5.0 Data Cleaning
# # 5.1 Data Creating

# %%
#Create a new column 'current_year'
df['current_year'] = 2024
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  current_year
# 0        2013            175.0    Action,Crime,Drama          2024
# 1        2019            114.0       Biography,Drama          2024
# 2        2018            122.0                 Drama          2024
# 3        2018              NaN          Comedy,Drama          2024
# 4        2017             80.0  Comedy,Drama,Fantasy          2024

# %%
#convert the 'start_year' into integer
year = np.array(df['start_year'])
df['start_year'] = year.astype(int)

#Create a new column 'age'
df['age'] = df['current_year'] - df['start_year']
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  current_year  age
# 0        2013            175.0    Action,Crime,Drama          2024   11
# 1        2019            114.0       Biography,Drama          2024    5
# 2        2018            122.0                 Drama          2024    6
# 3        2018              NaN          Comedy,Drama          2024    6
# 4        2017             80.0  Comedy,Drama,Fantasy          2024    7

# %%
#Create a new column named age_group
df['age_group'] = pd

# %% [markdown]
# # 5.2 Check for duplicate

# %%
#Checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 5.3 Check for null values

# %%
df.isnull().sum()
# Out:
# tconst                 0
# primary_title          1
# original_title        22
# start_year             0
# runtime_minutes    31739
# genres              5408
# current_year           0
# age                    0
# dtype: int64

# %% [markdown]
# # 5.4 Drop the Unique id.

# %%
#Dropping the Unique id column
df.drop('tconst',axis=1,inplace=True)
df.head()
# Out:
#                      primary_title              original_title  start_year  \
# 0                        Sunghursh                   Sunghursh        2013
# 1  One Day Before the Rainy Season             Ashad Ka Ek Din        2019
# 2       The Other Side of the Wind  The Other Side of the Wind        2018
# 3                  Sabse Bada Sukh             Sabse Bada Sukh        2018
# 4         The Wandering Soap Opera       La Telenovela Errante        2017
#
#    runtime_minutes                genres  current_year  age
# 0            175.0    Action,Crime,Drama          2024   11
# 1            114.0       Biography,Drama          2024    5
# 2            122.0                 Drama          2024    6
# 3              NaN          Comedy,Drama          2024    6
# 4             80.0  Comedy,Drama,Fantasy          2024    7

# %% [markdown]
# After dropping the tconst column,check aand align the column datatype

# %% [markdown]
# # 5.5 Checking and aligning column datatypes

# %%
#Checking column datatypes
df.dtypes
# Out:
# primary_title       object
# original_title      object
# start_year           int64
# runtime_minutes    float64
# genres              object
# current_year         int64
# age                  int64
# dtype: object

# %%
#Converting the year column to datetime datatype
df['start_year'] = pd.to_datetime(df['start_year'])
df.dtypes
# Out:
# primary_title              object
# original_title             object
# start_year         datetime64[ns]
# runtime_minutes           float64
# genres                     object
# current_year                int64
# age                         int64
# dtype: object

# %%
df
# Out:
#                                       primary_title  \
# 0                                         Sunghursh
# 1                   One Day Before the Rainy Season
# 2                        The Other Side of the Wind
# 3                                   Sabse Bada Sukh
# 4                          The Wandering Soap Opera
# ...                                             ...
# 146139                          Kuambil Lagi Hatiku
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141                              Dankyavar Danka
# 146142                                       6 Gunn
# 146143               Chico Albuquerque - Revelações
#
#                                      original_title  \
# 0                                         Sunghursh
# 1                                   Ashad Ka Ek Din
# 2                        The Other Side of the Wind
# 3                                   Sabse Bada Sukh
# 4                             La Telenovela Errante
# ...

# %%
#Exporting the cleaned dataset.
df.to_csv('Microsoft_movie_studio.csv')

# %% [markdown]
# # **Business Overview**

# %% [markdown]
# The best film made remains obstacle to creation of the movie studio.For example, in box office comedy and drama are the films that most studio thinks is the best.
#
# Films creation leads us to the genre column where we get to understand better how movie creation works and the best film to use.

# %% [markdown]
# # ANALYSIS
# After these processes the data will be clean to satisfactory degree and will now be ready for analysis which will be done both in pandas method and the sql method.
#
# This will be done using pandas as well as visualization tools available in the python libraries. This will mean both statistical values and visualisation of target variables will be displayed.
#
# Particular visualisation tools will be the seaborn and matplot library visualisation.

# %% [markdown]
# ## Problem Statement:
# This analysis into the problem statement will be the form of solving the following objectives questions:
#
# -To determine the number of genre in one movie in the genre column
#
# -To determine the movie which has the longest runtime
#
# -To determine the movie which had the shortest runtime
#
# -To determine the number of films created in particular movies in the movie market
#
# -To determine the percentage of number of films thats is in a movies
#
# -To determine the distribution of how old a movie is
#
# -To determine the movie with the most genre
#
# -To determine trend on age and runtime
#
# -To determine the trend between runtime within the dataset

# %% [markdown]
# Finally, having answered the objective questions, we will then conclude with an evaluation of the research which was based on the above problem statement.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Microsoft_movie_studio.csv")

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# primary_title       object
# original_title      object
# start_year          object
# runtime_minutes    float64
# genres              object
# current_year         int64
# age                  int64
# dtype: object

# %%
#The First research question is:
#To determine the number of film in one movie
A=df['genres'].str.split(',',expand=True)
A.head()
# Out:
#            0      1        2
# 0     Action  Crime    Drama
# 1  Biography  Drama     None
# 2      Drama   None     None
# 3     Comedy  Drama     None
# 4     Comedy  Drama  Fantasy

# %% [markdown]
# In the genre column, some movies had three types of films so we had to split it to be able to understand the movies with more than one film

# %%
#The Second research question is:
#To determine the longest movie in the dataset:
df['runtime_minutes'].max()
df[df['runtime_minutes']==df['runtime_minutes'].max()]
# Out:
#         Unnamed: 0 primary_title original_title  \
# 132389      132389     Logistics      Logistics
#
#                            start_year  runtime_minutes       genres  \
# 132389  1970-01-01 00:00:00.000002012          51420.0  Documentary
#
#         current_year  age
# 132389          2024   12

# %%
#The Third research question is:
#To determine the shortest movie in the dataset:
df['runtime_minutes'].min()
df[df['runtime_minutes']==df['runtime_minutes'].min()]
# Out:
#         Unnamed: 0                                      primary_title  \
# 2570          2570  Lamentation For Little Girls Who Are In Love W...
# 3298          3298                                     Happy New Year
# 22903        22903                                             Tierra
# 54307        54307   Guerreiros da paz e poesia: It All Depends on Us
# 57140        57140                                    Shark Sanctuary
# 60809        60809                                           November
# 72190        72190                         Powered By Green Smoothies
# 93214        93214             Great Valley Nature Center Documentary
# 95787        95787                        A Serendipitous Exploration
# 98755        98755                            Isa One Minute Portrait
# 113278      113278                                     First and Last
# 114067      114067                           One Minute Of Resistance
# ...

# %%
#The Forth research question is:
#To determine the number of films preffered in the movie markets:
df['genres'].value_counts()
# Out:
# genres
# Documentary                   32185
# Drama                         21486
# Comedy                         9177
# Horror                         4372
# Comedy,Drama                   3519
#                               ...
# Adventure,Music,Mystery           1
# Documentary,Horror,Romance        1
# Sport,Thriller                    1
# Comedy,Sport,Western              1
# Adventure,History,War             1
# Name: count, Length: 1085, dtype: int64

# %%
#The Fifth research question is:
#To determine the percentage of level of film preffered in the movie markets:
df['genres'].value_counts(normalize=True)
# Out:
# genres
# Documentary                   0.228691
# Drama                         0.152669
# Comedy                        0.065207
# Horror                        0.031065
# Comedy,Drama                  0.025004
#                                 ...
# Adventure,Music,Mystery       0.000007
# Documentary,Horror,Romance    0.000007
# Sport,Thriller                0.000007
# Comedy,Sport,Western          0.000007
# Adventure,History,War         0.000007
# Name: proportion, Length: 1085, dtype: float64

# %%
#The Sixth research question is:
#To sort the genre column in descending order:
df['genres'].sort_values(ascending=False)
# Out:
# 2424      Western
# 84579     Western
# 87695     Western
# 30841     Western
# 110875    Western
#            ...
# 146088        NaN
# 146089        NaN
# 146107        NaN
# 146129        NaN
# 146142        NaN
# Name: genres, Length: 146144, dtype: object

# %%
#The Seventh research question visualizes in the present distribution of the result:
#It will assist in identification of counts of ages
import seaborn as sns
import matplotlib.pyplot as plt

# Verify the column names in your DataFrame
print(df.columns)

plt.figure(figsize=(10,5))

# Replace 'ages' with the correct column name from your DataFrame
# if you want to analyze age distribution, or with another relevant column
sns.countplot(x='age', data=df).set(title ='Ages of movies')

plt.show()
# Out:
# Index(['Unnamed: 0', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'current_year', 'age'],
#       dtype='object')

# %%
#The eigth question is as follows:
#To determine the movie with the most film(genre)
df['genres'].value_counts().idxmax
df['genres'].head()
# Out:
# 0      Action,Crime,Drama
# 1         Biography,Drama
# 2                   Drama
# 3            Comedy,Drama
# 4    Comedy,Drama,Fantasy
# Name: genres, dtype: object

# %%
#The first visualisation will regard.
#Determination of trends on age and runtime
plt.figure(figsize=(10,5))
sns.lineplot(x='age', y='runtime_minutes',data=df).set(title='Trend on Ages and runtime')
# Out:
# [Text(0.5, 1.0, 'Trend on Ages and runtime')]

# %%
#The Second visualization will regard.
#Determination of the trends between the runtime within the datasets.
plt.figure(figsize=(10,5))
sns.countplot(x='runtime_minutes',data=df).set(title='Trend between runtime minutes')
plt.xlim(0,200)
plt.ylim(0,2000)
plt .show()

# %% [markdown]
# This means that the movies runtime in minutes is below 200 minutes.Actually most film range in 100 minutes having the longest number count

# %% [markdown]
# # RECOMMENDATION
# From our analysis, we would recommend that the Microsoft Movie Studio should target either comedy films or Documentary film since are the most created movies in the industry.
#
# The Movie should not surpass 200 minutes in the runtime since the movie loses count when they surpass 150 minutes hence having few views.
#
# Therefore, prioritizing the recommendation above would not only increase the investment but ensures the movie is suitable for all the age group. Also the Microsoft Movie Studio should focus on creating long-term movies
